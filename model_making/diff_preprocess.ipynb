# %%
import cv2

# %%
img = cv2.imread("/home/kazuh/Documents/UBC/ENPH_353/training_data/all_sessions/session_20251129_183752_466imgs/images/img_1996184000000.jpg")
img = cv2.resize(img, (160, 120))
img = cv2.Canny(img, threshold1=200, threshold2=220)
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread("/home/kazuh/Documents/UBC/ENPH_353/training_data/all_sessions/session_20251126_173028_839imgs/images/img_109786000000.jpg")
img = cv2.resize(img, (160, 120))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
