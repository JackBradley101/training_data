# %%
import cv2

# %%
img = cv2.imread("/home/kazuh/Documents/UBC/ENPH_353/training_data/all_sessions/session_20251126_173028_839imgs/images/img_109786000000.jpg")
img = cv2.resize(img, (160, 120))
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/kazuh/Documents/UBC/ENPH_353/training_data/model_making/JB_venv/lib/python3.13/site-packages/cv2/qt/plugins"

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
